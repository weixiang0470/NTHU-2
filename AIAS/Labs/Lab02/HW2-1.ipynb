# %% [markdown]
# # HW 2-1 Model Analysis Using Pytorch

# %%
import torchvision.models as models

# 加載 GoogLeNet 模型
model = models.googlenet(pretrained=True)
print(model)

input_shape = (3, 224, 224)
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=1000, bias=True)
# )

# %% [markdown]
# ## 2-1-1. Calculate the number of model parameters：
# - include all trainable and non-trainable parameters

# %%
# Calculating the total number of parameters in the model
total_params = sum(p.numel() for p in model.parameters())
print("Total number of parameters: ", total_params)
# Out:
# Total number of parameters:  6624904

# %% [markdown]
# ## 2-1-2. Calculate memory requirements for storing the model weights.

# %%
# Calculating the size of the model's parameters in bytes
param_size = sum(p.numel() * p.element_size() for p in model.parameters())
print("Total memory for parameters: ", param_size)
# Out:
# Total memory for parameters:  26499616

# %% [markdown]
# ## 2-1-3. Use Torchinfo to print model architecture including the number of parameters and the output activation size of each layer

# %%
from torchsummary import summary

# %%
summary(model, input_shape)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#        BasicConv2d-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#        BasicConv2d-7           [-1, 64, 56, 56]               0
#             Conv2d-8          [-1, 192, 56, 56]         110,592
#        BatchNorm2d-9          [-1, 192, 56, 56]             384
#       BasicConv2d-10          [-1, 192, 56, 56]               0
#         MaxPool2d-11          [-1, 192, 28, 28]               0
#            Conv2d-12           [-1, 64, 28, 28]          12,288
#       BatchNorm2d-13           [-1, 64, 28, 28]             128
#       BasicConv2d-14           [-1, 64, 28, 28]               0
#            Conv2d-15           [-1, 96, 28, 28]          18,432
#       BatchNorm2d-16           [-1, 96, 28, 28]             192
#       BasicConv2d-17           [-1, 96, 28, 28]               0
#            Conv2d-18          [-1, 128, 28, 28]         110,592
#       BatchNorm2d-19          [-1, 128, 28, 28]             256
#       BasicConv2d-20          [-1, 128, 28, 28]               0
#            Conv2d-21           [-1, 16, 28, 28]           3,072
#       BatchNorm2d-22           [-1, 16, 28, 28]              32
#       BasicConv2d-23           [-1, 16, 28, 28]               0
#            Conv2d-24           [-1, 32, 28, 28]           4,608
#       BatchNorm2d-25           [-1, 32, 28, 28]              64
#       BasicConv2d-26           [-1, 32, 28, 28]               0
#         MaxPool2d-27          [-1, 192, 28, 28]               0
#            Conv2d-28           [-1, 32, 28, 28]           6,144
#       BatchNorm2d-29           [-1, 32, 28, 28]              64
#       BasicConv2d-30           [-1, 32, 28, 28]               0
#         Inception-31          [-1, 256, 28, 28]               0
#            Conv2d-32          [-1, 128, 28, 28]          32,768
#       BatchNorm2d-33          [-1, 128, 28, 28]             256
#       BasicConv2d-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 128, 28, 28]          32,768
#       BatchNorm2d-36          [-1, 128, 28, 28]             256
#       BasicConv2d-37          [-1, 128, 28, 28]               0
#            Conv2d-38          [-1, 192, 28, 28]         221,184
#       BatchNorm2d-39          [-1, 192, 28, 28]             384
#       BasicConv2d-40          [-1, 192, 28, 28]               0
#            Conv2d-41           [-1, 32, 28, 28]           8,192
#       BatchNorm2d-42           [-1, 32, 28, 28]              64
#       BasicConv2d-43           [-1, 32, 28, 28]               0
#            Conv2d-44           [-1, 96, 28, 28]          27,648
#       BatchNorm2d-45           [-1, 96, 28, 28]             192
#       BasicConv2d-46           [-1, 96, 28, 28]               0
#         MaxPool2d-47          [-1, 256, 28, 28]               0
#            Conv2d-48           [-1, 64, 28, 28]          16,384
#       BatchNorm2d-49           [-1, 64, 28, 28]             128
#       BasicConv2d-50           [-1, 64, 28, 28]               0
#         Inception-51          [-1, 480, 28, 28]               0
#         MaxPool2d-52          [-1, 480, 14, 14]               0
#            Conv2d-53          [-1, 192, 14, 14]          92,160
#       BatchNorm2d-54          [-1, 192, 14, 14]             384
#       BasicConv2d-55          [-1, 192, 14, 14]               0
#            Conv2d-56           [-1, 96, 14, 14]          46,080
#       BatchNorm2d-57           [-1, 96, 14, 14]             192
#       BasicConv2d-58           [-1, 96, 14, 14]               0
#            Conv2d-59          [-1, 208, 14, 14]         179,712
#       BatchNorm2d-60          [-1, 208, 14, 14]             416
#       BasicConv2d-61          [-1, 208, 14, 14]               0
#            Conv2d-62           [-1, 16, 14, 14]           7,680
#       BatchNorm2d-63           [-1, 16, 14, 14]              32
#       BasicConv2d-64           [-1, 16, 14, 14]               0
#            Conv2d-65           [-1, 48, 14, 14]           6,912
#       BatchNorm2d-66           [-1, 48, 14, 14]              96
#       BasicConv2d-67           [-1, 48, 14, 14]               0
#         MaxPool2d-68          [-1, 480, 14, 14]               0
#            Conv2d-69           [-1, 64, 14, 14]          30,720
#       BatchNorm2d-70           [-1, 64, 14, 14]             128
#       BasicConv2d-71           [-1, 64, 14, 14]               0
#         Inception-72          [-1, 512, 14, 14]               0
#            Conv2d-73          [-1, 160, 14, 14]          81,920
#       BatchNorm2d-74          [-1, 160, 14, 14]             320
#       BasicConv2d-75          [-1, 160, 14, 14]               0
#            Conv2d-76          [-1, 112, 14, 14]          57,344
#       BatchNorm2d-77          [-1, 112, 14, 14]             224
#       BasicConv2d-78          [-1, 112, 14, 14]               0
#            Conv2d-79          [-1, 224, 14, 14]         225,792
#       BatchNorm2d-80          [-1, 224, 14, 14]             448
#       BasicConv2d-81          [-1, 224, 14, 14]               0
#            Conv2d-82           [-1, 24, 14, 14]          12,288
#       BatchNorm2d-83           [-1, 24, 14, 14]              48
#       BasicConv2d-84           [-1, 24, 14, 14]               0
#            Conv2d-85           [-1, 64, 14, 14]          13,824
#       BatchNorm2d-86           [-1, 64, 14, 14]             128
#       BasicConv2d-87           [-1, 64, 14, 14]               0
#         MaxPool2d-88          [-1, 512, 14, 14]               0
#            Conv2d-89           [-1, 64, 14, 14]          32,768
#       BatchNorm2d-90           [-1, 64, 14, 14]             128
#       BasicConv2d-91           [-1, 64, 14, 14]               0
#         Inception-92          [-1, 512, 14, 14]               0
#            Conv2d-93          [-1, 128, 14, 14]          65,536
#       BatchNorm2d-94          [-1, 128, 14, 14]             256
#       BasicConv2d-95          [-1, 128, 14, 14]               0
#            Conv2d-96          [-1, 128, 14, 14]          65,536
#       BatchNorm2d-97          [-1, 128, 14, 14]             256
#       BasicConv2d-98          [-1, 128, 14, 14]               0
#            Conv2d-99          [-1, 256, 14, 14]         294,912
#      BatchNorm2d-100          [-1, 256, 14, 14]             512
#      BasicConv2d-101          [-1, 256, 14, 14]               0
#           Conv2d-102           [-1, 24, 14, 14]          12,288
#      BatchNorm2d-103           [-1, 24, 14, 14]              48
#      BasicConv2d-104           [-1, 24, 14, 14]               0
#           Conv2d-105           [-1, 64, 14, 14]          13,824
#      BatchNorm2d-106           [-1, 64, 14, 14]             128
#      BasicConv2d-107           [-1, 64, 14, 14]               0
#        MaxPool2d-108          [-1, 512, 14, 14]               0
#           Conv2d-109           [-1, 64, 14, 14]          32,768
#      BatchNorm2d-110           [-1, 64, 14, 14]             128
#      BasicConv2d-111           [-1, 64, 14, 14]               0
#        Inception-112          [-1, 512, 14, 14]               0
#           Conv2d-113          [-1, 112, 14, 14]          57,344
#      BatchNorm2d-114          [-1, 112, 14, 14]             224
#      BasicConv2d-115          [-1, 112, 14, 14]               0
#           Conv2d-116          [-1, 144, 14, 14]          73,728
#      BatchNorm2d-117          [-1, 144, 14, 14]             288
#      BasicConv2d-118          [-1, 144, 14, 14]               0
#           Conv2d-119          [-1, 288, 14, 14]         373,248
#      BatchNorm2d-120          [-1, 288, 14, 14]             576
#      BasicConv2d-121          [-1, 288, 14, 14]               0
#           Conv2d-122           [-1, 32, 14, 14]          16,384
#      BatchNorm2d-123           [-1, 32, 14, 14]              64
#      BasicConv2d-124           [-1, 32, 14, 14]               0
#           Conv2d-125           [-1, 64, 14, 14]          18,432
#      BatchNorm2d-126           [-1, 64, 14, 14]             128
#      BasicConv2d-127           [-1, 64, 14, 14]               0
#        MaxPool2d-128          [-1, 512, 14, 14]               0
#           Conv2d-129           [-1, 64, 14, 14]          32,768
#      BatchNorm2d-130           [-1, 64, 14, 14]             128
#      BasicConv2d-131           [-1, 64, 14, 14]               0
#        Inception-132          [-1, 528, 14, 14]               0
#           Conv2d-133          [-1, 256, 14, 14]         135,168
#      BatchNorm2d-134          [-1, 256, 14, 14]             512
#      BasicConv2d-135          [-1, 256, 14, 14]               0
#           Conv2d-136          [-1, 160, 14, 14]          84,480
#      BatchNorm2d-137          [-1, 160, 14, 14]             320
#      BasicConv2d-138          [-1, 160, 14, 14]               0
#           Conv2d-139          [-1, 320, 14, 14]         460,800
#      BatchNorm2d-140          [-1, 320, 14, 14]             640
#      BasicConv2d-141          [-1, 320, 14, 14]               0
#           Conv2d-142           [-1, 32, 14, 14]          16,896
#      BatchNorm2d-143           [-1, 32, 14, 14]              64
#      BasicConv2d-144           [-1, 32, 14, 14]               0
#           Conv2d-145          [-1, 128, 14, 14]          36,864
#      BatchNorm2d-146          [-1, 128, 14, 14]             256
#      BasicConv2d-147          [-1, 128, 14, 14]               0
#        MaxPool2d-148          [-1, 528, 14, 14]               0
#           Conv2d-149          [-1, 128, 14, 14]          67,584
#      BatchNorm2d-150          [-1, 128, 14, 14]             256
#      BasicConv2d-151          [-1, 128, 14, 14]               0
#        Inception-152          [-1, 832, 14, 14]               0
#        MaxPool2d-153            [-1, 832, 7, 7]               0
#           Conv2d-154            [-1, 256, 7, 7]         212,992
#      BatchNorm2d-155            [-1, 256, 7, 7]             512
#      BasicConv2d-156            [-1, 256, 7, 7]               0
#           Conv2d-157            [-1, 160, 7, 7]         133,120
#      BatchNorm2d-158            [-1, 160, 7, 7]             320
#      BasicConv2d-159            [-1, 160, 7, 7]               0
#           Conv2d-160            [-1, 320, 7, 7]         460,800
#      BatchNorm2d-161            [-1, 320, 7, 7]             640
#      BasicConv2d-162            [-1, 320, 7, 7]               0
#           Conv2d-163             [-1, 32, 7, 7]          26,624
#      BatchNorm2d-164             [-1, 32, 7, 7]              64
#      BasicConv2d-165             [-1, 32, 7, 7]               0
#           Conv2d-166            [-1, 128, 7, 7]          36,864
#      BatchNorm2d-167            [-1, 128, 7, 7]             256
#      BasicConv2d-168            [-1, 128, 7, 7]               0
#        MaxPool2d-169            [-1, 832, 7, 7]               0
#           Conv2d-170            [-1, 128, 7, 7]         106,496
#      BatchNorm2d-171            [-1, 128, 7, 7]             256
#      BasicConv2d-172            [-1, 128, 7, 7]               0
#        Inception-173            [-1, 832, 7, 7]               0
#           Conv2d-174            [-1, 384, 7, 7]         319,488
#      BatchNorm2d-175            [-1, 384, 7, 7]             768
#      BasicConv2d-176            [-1, 384, 7, 7]               0
#           Conv2d-177            [-1, 192, 7, 7]         159,744
#      BatchNorm2d-178            [-1, 192, 7, 7]             384
#      BasicConv2d-179            [-1, 192, 7, 7]               0
#           Conv2d-180            [-1, 384, 7, 7]         663,552
#      BatchNorm2d-181            [-1, 384, 7, 7]             768
#      BasicConv2d-182            [-1, 384, 7, 7]               0
#           Conv2d-183             [-1, 48, 7, 7]          39,936
#      BatchNorm2d-184             [-1, 48, 7, 7]              96
#      BasicConv2d-185             [-1, 48, 7, 7]               0
#           Conv2d-186            [-1, 128, 7, 7]          55,296
#      BatchNorm2d-187            [-1, 128, 7, 7]             256
#      BasicConv2d-188            [-1, 128, 7, 7]               0
#        MaxPool2d-189            [-1, 832, 7, 7]               0
#           Conv2d-190            [-1, 128, 7, 7]         106,496
#      BatchNorm2d-191            [-1, 128, 7, 7]             256
#      BasicConv2d-192            [-1, 128, 7, 7]               0
#        Inception-193           [-1, 1024, 7, 7]               0
# AdaptiveAvgPool2d-194           [-1, 1024, 1, 1]               0
#          Dropout-195                 [-1, 1024]               0
#           Linear-196                 [-1, 1000]       1,025,000
# ================================================================
# Total params: 6,624,904
# Trainable params: 6,624,904
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 94.11
# Params size (MB): 25.27
# Estimated Total Size (MB): 119.95
# ----------------------------------------------------------------

# %% [markdown]
# ## 2-1-4. Calculate computation requirements
# - The primary focus is on calculating MACs for linear and convolutional layers, with calculations for other layers being a bonus.
# - Hint: Since the MAC calculation example in the lab2-3-3 is specifically for AlexNet, it needs to be modified for use with other models.

# %%
import torchinfo
summary = torchinfo.summary(model, input_shape, batch_dim=0, col_names=("input_size", "output_size", "num_params", "mult_adds"), verbose=1)
total_macs = summary.total_mult_adds
print(total_macs)
# Out:
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Mult-Adds
# ============================================================================================================================================
# GoogLeNet                                [1, 3, 224, 224]          [1, 1000]                 --                        --
# ├─BasicConv2d: 1-1                       [1, 3, 224, 224]          [1, 64, 112, 112]         --                        --
# │    └─Conv2d: 2-1                       [1, 3, 224, 224]          [1, 64, 112, 112]         9,408                     118,013,952
# │    └─BatchNorm2d: 2-2                  [1, 64, 112, 112]         [1, 64, 112, 112]         128                       128
# ├─MaxPool2d: 1-2                         [1, 64, 112, 112]         [1, 64, 56, 56]           --                        --
# ├─BasicConv2d: 1-3                       [1, 64, 56, 56]           [1, 64, 56, 56]           --                        --
# │    └─Conv2d: 2-3                       [1, 64, 56, 56]           [1, 64, 56, 56]           4,096                     12,845,056
# │    └─BatchNorm2d: 2-4                  [1, 64, 56, 56]           [1, 64, 56, 56]           128                       128
# ├─BasicConv2d: 1-4                       [1, 64, 56, 56]           [1, 192, 56, 56]          --                        --
# │    └─Conv2d: 2-5                       [1, 64, 56, 56]           [1, 192, 56, 56]          110,592                   346,816,512
# │    └─BatchNorm2d: 2-6                  [1, 192, 56, 56]          [1, 192, 56, 56]          384                       384
# ├─MaxPool2d: 1-5                         [1, 192, 56, 56]          [1, 192, 28, 28]          --                        --
# ├─Inception: 1-6                         [1, 192, 28, 28]          [1, 256, 28, 28]          --                        --
# │    └─BasicConv2d: 2-7                  [1, 192, 28, 28]          [1, 64, 28, 28]           --                        --
# │    │    └─Conv2d: 3-1                  [1, 192, 28, 28]          [1, 64, 28, 28]           12,288                    9,633,792
# │    │    └─BatchNorm2d: 3-2             [1, 64, 28, 28]           [1, 64, 28, 28]           128                       128
# │    └─Sequential: 2-8                   [1, 192, 28, 28]          [1, 128, 28, 28]          --                        --
# │    │    └─BasicConv2d: 3-3             [1, 192, 28, 28]          [1, 96, 28, 28]           18,624                    14,450,880
# │    │    └─BasicConv2d: 3-4             [1, 96, 28, 28]           [1, 128, 28, 28]          110,848                   86,704,384
# │    └─Sequential: 2-9                   [1, 192, 28, 28]          [1, 32, 28, 28]           --                        --
# │    │    └─BasicConv2d: 3-5             [1, 192, 28, 28]          [1, 16, 28, 28]           3,104                     2,408,480
# │    │    └─BasicConv2d: 3-6             [1, 16, 28, 28]           [1, 32, 28, 28]           4,672                     3,612,736
# │    └─Sequential: 2-10                  [1, 192, 28, 28]          [1, 32, 28, 28]           --                        --
# │    │    └─MaxPool2d: 3-7               [1, 192, 28, 28]          [1, 192, 28, 28]          --                        --
# │    │    └─BasicConv2d: 3-8             [1, 192, 28, 28]          [1, 32, 28, 28]           6,208                     4,816,960
# ├─Inception: 1-7                         [1, 256, 28, 28]          [1, 480, 28, 28]          --                        --
# │    └─BasicConv2d: 2-11                 [1, 256, 28, 28]          [1, 128, 28, 28]          --                        --
# │    │    └─Conv2d: 3-9                  [1, 256, 28, 28]          [1, 128, 28, 28]          32,768                    25,690,112
# │    │    └─BatchNorm2d: 3-10            [1, 128, 28, 28]          [1, 128, 28, 28]          256                       256
# │    └─Sequential: 2-12                  [1, 256, 28, 28]          [1, 192, 28, 28]          --                        --
# │    │    └─BasicConv2d: 3-11            [1, 256, 28, 28]          [1, 128, 28, 28]          33,024                    25,690,368
# │    │    └─BasicConv2d: 3-12            [1, 128, 28, 28]          [1, 192, 28, 28]          221,568                   173,408,640
# │    └─Sequential: 2-13                  [1, 256, 28, 28]          [1, 96, 28, 28]           --                        --
# │    │    └─BasicConv2d: 3-13            [1, 256, 28, 28]          [1, 32, 28, 28]           8,256                     6,422,592
# │    │    └─BasicConv2d: 3-14            [1, 32, 28, 28]           [1, 96, 28, 28]           27,840                    21,676,224
# │    └─Sequential: 2-14                  [1, 256, 28, 28]          [1, 64, 28, 28]           --                        --
# │    │    └─MaxPool2d: 3-15              [1, 256, 28, 28]          [1, 256, 28, 28]          --                        --
# │    │    └─BasicConv2d: 3-16            [1, 256, 28, 28]          [1, 64, 28, 28]           16,512                    12,845,184
# ├─MaxPool2d: 1-8                         [1, 480, 28, 28]          [1, 480, 14, 14]          --                        --
# ├─Inception: 1-9                         [1, 480, 14, 14]          [1, 512, 14, 14]          --                        --
# │    └─BasicConv2d: 2-15                 [1, 480, 14, 14]          [1, 192, 14, 14]          --                        --
# │    │    └─Conv2d: 3-17                 [1, 480, 14, 14]          [1, 192, 14, 14]          92,160                    18,063,360
# │    │    └─BatchNorm2d: 3-18            [1, 192, 14, 14]          [1, 192, 14, 14]          384                       384
# │    └─Sequential: 2-16                  [1, 480, 14, 14]          [1, 208, 14, 14]          --                        --
# │    │    └─BasicConv2d: 3-19            [1, 480, 14, 14]          [1, 96, 14, 14]           46,272                    9,031,872
# │    │    └─BasicConv2d: 3-20            [1, 96, 14, 14]           [1, 208, 14, 14]          180,128                   35,223,968
# │    └─Sequential: 2-17                  [1, 480, 14, 14]          [1, 48, 14, 14]           --                        --
# │    │    └─BasicConv2d: 3-21            [1, 480, 14, 14]          [1, 16, 14, 14]           7,712                     1,505,312
# │    │    └─BasicConv2d: 3-22            [1, 16, 14, 14]           [1, 48, 14, 14]           7,008                     1,354,848
# │    └─Sequential: 2-18                  [1, 480, 14, 14]          [1, 64, 14, 14]           --                        --
# │    │    └─MaxPool2d: 3-23              [1, 480, 14, 14]          [1, 480, 14, 14]          --                        --
# │    │    └─BasicConv2d: 3-24            [1, 480, 14, 14]          [1, 64, 14, 14]           30,848                    6,021,248
# ├─Inception: 1-10                        [1, 512, 14, 14]          [1, 512, 14, 14]          --                        --
# │    └─BasicConv2d: 2-19                 [1, 512, 14, 14]          [1, 160, 14, 14]          --                        --
# │    │    └─Conv2d: 3-25                 [1, 512, 14, 14]          [1, 160, 14, 14]          81,920                    16,056,320
# │    │    └─BatchNorm2d: 3-26            [1, 160, 14, 14]          [1, 160, 14, 14]          320                       320
# │    └─Sequential: 2-20                  [1, 512, 14, 14]          [1, 224, 14, 14]          --                        --
# │    │    └─BasicConv2d: 3-27            [1, 512, 14, 14]          [1, 112, 14, 14]          57,568                    11,239,648
# │    │    └─BasicConv2d: 3-28            [1, 112, 14, 14]          [1, 224, 14, 14]          226,240                   44,255,680
# │    └─Sequential: 2-21                  [1, 512, 14, 14]          [1, 64, 14, 14]           --                        --
# │    │    └─BasicConv2d: 3-29            [1, 512, 14, 14]          [1, 24, 14, 14]           12,336                    2,408,496
# │    │    └─BasicConv2d: 3-30            [1, 24, 14, 14]           [1, 64, 14, 14]           13,952                    2,709,632
# │    └─Sequential: 2-22                  [1, 512, 14, 14]          [1, 64, 14, 14]           --                        --
# │    │    └─MaxPool2d: 3-31              [1, 512, 14, 14]          [1, 512, 14, 14]          --                        --
# │    │    └─BasicConv2d: 3-32            [1, 512, 14, 14]          [1, 64, 14, 14]           32,896                    6,422,656
# ├─Inception: 1-11                        [1, 512, 14, 14]          [1, 512, 14, 14]          --                        --
# │    └─BasicConv2d: 2-23                 [1, 512, 14, 14]          [1, 128, 14, 14]          --                        --
# │    │    └─Conv2d: 3-33                 [1, 512, 14, 14]          [1, 128, 14, 14]          65,536                    12,845,056
# │    │    └─BatchNorm2d: 3-34            [1, 128, 14, 14]          [1, 128, 14, 14]          256                       256
# │    └─Sequential: 2-24                  [1, 512, 14, 14]          [1, 256, 14, 14]          --                        --
# │    │    └─BasicConv2d: 3-35            [1, 512, 14, 14]          [1, 128, 14, 14]          65,792                    12,845,312
# │    │    └─BasicConv2d: 3-36            [1, 128, 14, 14]          [1, 256, 14, 14]          295,424                   57,803,264
# │    └─Sequential: 2-25                  [1, 512, 14, 14]          [1, 64, 14, 14]           --                        --
# │    │    └─BasicConv2d: 3-37            [1, 512, 14, 14]          [1, 24, 14, 14]           12,336                    2,408,496
# │    │    └─BasicConv2d: 3-38            [1, 24, 14, 14]           [1, 64, 14, 14]           13,952                    2,709,632
# │    └─Sequential: 2-26                  [1, 512, 14, 14]          [1, 64, 14, 14]           --                        --
# │    │    └─MaxPool2d: 3-39              [1, 512, 14, 14]          [1, 512, 14, 14]          --                        --
# │    │    └─BasicConv2d: 3-40            [1, 512, 14, 14]          [1, 64, 14, 14]           32,896                    6,422,656
# ├─Inception: 1-12                        [1, 512, 14, 14]          [1, 528, 14, 14]          --                        --
# │    └─BasicConv2d: 2-27                 [1, 512, 14, 14]          [1, 112, 14, 14]          --                        --
# │    │    └─Conv2d: 3-41                 [1, 512, 14, 14]          [1, 112, 14, 14]          57,344                    11,239,424
# │    │    └─BatchNorm2d: 3-42            [1, 112, 14, 14]          [1, 112, 14, 14]          224                       224
# │    └─Sequential: 2-28                  [1, 512, 14, 14]          [1, 288, 14, 14]          --                        --
# │    │    └─BasicConv2d: 3-43            [1, 512, 14, 14]          [1, 144, 14, 14]          74,016                    14,450,976
# │    │    └─BasicConv2d: 3-44            [1, 144, 14, 14]          [1, 288, 14, 14]          373,824                   73,157,184
# │    └─Sequential: 2-29                  [1, 512, 14, 14]          [1, 64, 14, 14]           --                        --
# │    │    └─BasicConv2d: 3-45            [1, 512, 14, 14]          [1, 32, 14, 14]           16,448                    3,211,328
# │    │    └─BasicConv2d: 3-46            [1, 32, 14, 14]           [1, 64, 14, 14]           18,560                    3,612,800
# │    └─Sequential: 2-30                  [1, 512, 14, 14]          [1, 64, 14, 14]           --                        --
# │    │    └─MaxPool2d: 3-47              [1, 512, 14, 14]          [1, 512, 14, 14]          --                        --
# │    │    └─BasicConv2d: 3-48            [1, 512, 14, 14]          [1, 64, 14, 14]           32,896                    6,422,656
# ├─Inception: 1-13                        [1, 528, 14, 14]          [1, 832, 14, 14]          --                        --
# │    └─BasicConv2d: 2-31                 [1, 528, 14, 14]          [1, 256, 14, 14]          --                        --
# │    │    └─Conv2d: 3-49                 [1, 528, 14, 14]          [1, 256, 14, 14]          135,168                   26,492,928
# │    │    └─BatchNorm2d: 3-50            [1, 256, 14, 14]          [1, 256, 14, 14]          512                       512
# │    └─Sequential: 2-32                  [1, 528, 14, 14]          [1, 320, 14, 14]          --                        --
# │    │    └─BasicConv2d: 3-51            [1, 528, 14, 14]          [1, 160, 14, 14]          84,800                    16,558,400
# │    │    └─BasicConv2d: 3-52            [1, 160, 14, 14]          [1, 320, 14, 14]          461,440                   90,317,440
# │    └─Sequential: 2-33                  [1, 528, 14, 14]          [1, 128, 14, 14]          --                        --
# │    │    └─BasicConv2d: 3-53            [1, 528, 14, 14]          [1, 32, 14, 14]           16,960                    3,311,680
# │    │    └─BasicConv2d: 3-54            [1, 32, 14, 14]           [1, 128, 14, 14]          37,120                    7,225,600
# │    └─Sequential: 2-34                  [1, 528, 14, 14]          [1, 128, 14, 14]          --                        --
# │    │    └─MaxPool2d: 3-55              [1, 528, 14, 14]          [1, 528, 14, 14]          --                        --
# │    │    └─BasicConv2d: 3-56            [1, 528, 14, 14]          [1, 128, 14, 14]          67,840                    13,246,720
# ├─MaxPool2d: 1-14                        [1, 832, 14, 14]          [1, 832, 7, 7]            --                        --
# ├─Inception: 1-15                        [1, 832, 7, 7]            [1, 832, 7, 7]            --                        --
# │    └─BasicConv2d: 2-35                 [1, 832, 7, 7]            [1, 256, 7, 7]            --                        --
# │    │    └─Conv2d: 3-57                 [1, 832, 7, 7]            [1, 256, 7, 7]            212,992                   10,436,608
# │    │    └─BatchNorm2d: 3-58            [1, 256, 7, 7]            [1, 256, 7, 7]            512                       512
# │    └─Sequential: 2-36                  [1, 832, 7, 7]            [1, 320, 7, 7]            --                        --
# │    │    └─BasicConv2d: 3-59            [1, 832, 7, 7]            [1, 160, 7, 7]            133,440                   6,523,200
# │    │    └─BasicConv2d: 3-60            [1, 160, 7, 7]            [1, 320, 7, 7]            461,440                   22,579,840
# │    └─Sequential: 2-37                  [1, 832, 7, 7]            [1, 128, 7, 7]            --                        --
# │    │    └─BasicConv2d: 3-61            [1, 832, 7, 7]            [1, 32, 7, 7]             26,688                    1,304,640
# │    │    └─BasicConv2d: 3-62            [1, 32, 7, 7]             [1, 128, 7, 7]            37,120                    1,806,592
# │    └─Sequential: 2-38                  [1, 832, 7, 7]            [1, 128, 7, 7]            --                        --
# │    │    └─MaxPool2d: 3-63              [1, 832, 7, 7]            [1, 832, 7, 7]            --                        --
# │    │    └─BasicConv2d: 3-64            [1, 832, 7, 7]            [1, 128, 7, 7]            106,752                   5,218,560
# ├─Inception: 1-16                        [1, 832, 7, 7]            [1, 1024, 7, 7]           --                        --
# │    └─BasicConv2d: 2-39                 [1, 832, 7, 7]            [1, 384, 7, 7]            --                        --
# │    │    └─Conv2d: 3-65                 [1, 832, 7, 7]            [1, 384, 7, 7]            319,488                   15,654,912
# │    │    └─BatchNorm2d: 3-66            [1, 384, 7, 7]            [1, 384, 7, 7]            768                       768
# │    └─Sequential: 2-40                  [1, 832, 7, 7]            [1, 384, 7, 7]            --                        --
# │    │    └─BasicConv2d: 3-67            [1, 832, 7, 7]            [1, 192, 7, 7]            160,128                   7,827,840
# │    │    └─BasicConv2d: 3-68            [1, 192, 7, 7]            [1, 384, 7, 7]            664,320                   32,514,816
# │    └─Sequential: 2-41                  [1, 832, 7, 7]            [1, 128, 7, 7]            --                        --
# │    │    └─BasicConv2d: 3-69            [1, 832, 7, 7]            [1, 48, 7, 7]             40,032                    1,956,960
# │    │    └─BasicConv2d: 3-70            [1, 48, 7, 7]             [1, 128, 7, 7]            55,552                    2,709,760
# │    └─Sequential: 2-42                  [1, 832, 7, 7]            [1, 128, 7, 7]            --                        --
# │    │    └─MaxPool2d: 3-71              [1, 832, 7, 7]            [1, 832, 7, 7]            --                        --
# │    │    └─BasicConv2d: 3-72            [1, 832, 7, 7]            [1, 128, 7, 7]            106,752                   5,218,560
# ├─AdaptiveAvgPool2d: 1-17                [1, 1024, 7, 7]           [1, 1024, 1, 1]           --                        --
# ├─Dropout: 1-18                          [1, 1024]                 [1, 1024]                 --                        --
# ├─Linear: 1-19                           [1, 1024]                 [1, 1000]                 1,025,000                 1,025,000
# ============================================================================================================================================
# Total params: 6,624,904
# Trainable params: 6,624,904
# Non-trainable params: 0
# Total mult-adds (G): 1.50
# ============================================================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 51.63
# Params size (MB): 26.50
# Estimated Total Size (MB): 78.73
# ============================================================================================================================================
# 1498391752

# %%
import torch
import torchvision.models as models
import torch.nn as nn
def calculate_output_shape(input_shape, layer):
    # Calculate the output shape for Conv2d, MaxPool2d, and Linear layers
    if isinstance(layer, (nn.Conv2d, nn.MaxPool2d)):
        kernel_size = (
            layer.kernel_size
            if isinstance(layer.kernel_size, tuple)
            else (layer.kernel_size, layer.kernel_size)
        )
        stride = (
            layer.stride
            if isinstance(layer.stride, tuple)
            else (layer.stride, layer.stride)
        )
        padding = (
            layer.padding
            if isinstance(layer.padding, tuple)
            else (layer.padding, layer.padding)
        )
        dilation = (
            layer.dilation
            if isinstance(layer.dilation, tuple)
            else (layer.dilation, layer.dilation)
        )

        if isinstance(layer, nn.MaxPool2d) and hasattr(layer, 'ceil_mode') and layer.ceil_mode:
            # 使用向上取整
            import math
            output_height = math.ceil((input_shape[1] + 2 * padding[0] - kernel_size[0]) / stride[0]) + 1
            output_width = math.ceil((input_shape[2] + 2 * padding[1] - kernel_size[1]) / stride[1]) + 1
        else:
            # 使用原公式（適用於 Conv2d 或 ceil_mode=False 的 MaxPool2d）
            output_height = (
                input_shape[1] + 2 * padding[0] - dilation[0] * (kernel_size[0] - 1) - 1
            ) // stride[0] + 1
            output_width = (
                input_shape[2] + 2 * padding[1] - dilation[1] * (kernel_size[1] - 1) - 1
            ) // stride[1] + 1
        
        return (
            layer.out_channels if hasattr(layer, "out_channels") else input_shape[0],
            output_height,
            output_width,
        )
    elif isinstance(layer, nn.Linear):
        # For Linear layers, the output shape is simply the layer's output features
        return (layer.out_features,)
    else:
        return input_shape


def calculate_macs(layer, input_shape, output_shape):
    # Calculate MACs for Conv2d and Linear layers
    if isinstance(layer, nn.Conv2d):
        kernel_ops = (
            layer.kernel_size[0]
            * layer.kernel_size[1]
            * (layer.in_channels / layer.groups)
        )
        output_elements = output_shape[1] * output_shape[2]
        macs = int(kernel_ops * output_elements * layer.out_channels)
        return macs
    elif isinstance(layer, nn.BatchNorm2d):
        # print(f"找到 BatchNorm2d 層：{name}, MACs：{}")
        macs = int(output_shape[0] * 2)
        return macs
    elif isinstance(layer, nn.Linear):
        # For Linear layers, MACs are the product of input features and output features
        macs = int(layer.in_features * layer.out_features + (layer.out_features if layer.bias is not None else 0))
        return macs
    else:
        return 0

# %%
# Initial input shape
input_shape = (3, 224, 224)
total_macs = 0

# Iterate through the layers of the model
for name, layer in model.named_modules():
    if isinstance(layer, (nn.Conv2d, nn.MaxPool2d, nn.ReLU, nn.Linear,nn.BatchNorm2d)):
        output_shape = calculate_output_shape(input_shape, layer)
        macs = calculate_macs(layer, input_shape, output_shape)
        total_macs += macs
        if isinstance(layer, (nn.Conv2d, nn.Linear,nn.BatchNorm2d)):
            print(
                f"Layer: {name}, Type: {type(layer).__name__}, Input Shape: {input_shape}, Output Shape: {output_shape}, MACs: {macs}"
            )
        elif isinstance(layer, nn.MaxPool2d):
            # Also print shape transformation for MaxPool2d layers (no MACs calculated)
            print(
                f"Layer: {name}, Type: {type(layer).__name__}, Input Shape: {input_shape}, Output Shape: {output_shape}, MACs: N/A"
            )
        input_shape = output_shape  # Update the input shape for the next layer

print(f"Total MACs: {total_macs}")
# Out:
# Layer: conv1.conv, Type: Conv2d, Input Shape: (3, 224, 224), Output Shape: (64, 112, 112), MACs: 118013952
# Layer: conv1.bn, Type: BatchNorm2d, Input Shape: (64, 112, 112), Output Shape: (64, 112, 112), MACs: 128
# Layer: maxpool1, Type: MaxPool2d, Input Shape: (64, 112, 112), Output Shape: (64, 56, 56), MACs: N/A
# Layer: conv2.conv, Type: Conv2d, Input Shape: (64, 56, 56), Output Shape: (64, 56, 56), MACs: 12845056
# Layer: conv2.bn, Type: BatchNorm2d, Input Shape: (64, 56, 56), Output Shape: (64, 56, 56), MACs: 128
# Layer: conv3.conv, Type: Conv2d, Input Shape: (64, 56, 56), Output Shape: (192, 56, 56), MACs: 346816512
# Layer: conv3.bn, Type: BatchNorm2d, Input Shape: (192, 56, 56), Output Shape: (192, 56, 56), MACs: 384
# Layer: maxpool2, Type: MaxPool2d, Input Shape: (192, 56, 56), Output Shape: (192, 28, 28), MACs: N/A
# Layer: inception3a.branch1.conv, Type: Conv2d, Input Shape: (192, 28, 28), Output Shape: (64, 28, 28), MACs: 9633792
# Layer: inception3a.branch1.bn, Type: BatchNorm2d, Input Shape: (64, 28, 28), Output Shape: (64, 28, 28), MACs: 128
# Layer: inception3a.branch2.0.conv, Type: Conv2d, Input Shape: (64, 28, 28), Output Shape: (96, 28, 28), MACs: 14450688
# Layer: inception3a.branch2.0.bn, Type: BatchNorm2d, Input Shape: (96, 28, 28), Output Shape: (96, 28, 28), MACs: 192
# Layer: inception3a.branch2.1.conv, Type: Conv2d, Input Shape: (96, 28, 28), Output Shape: (128, 28, 28), MACs: 86704128
# Layer: inception3a.branch2.1.bn, Type: BatchNorm2d, Input Shape: (128, 28, 28), Output Shape: (128, 28, 28), MACs: 256
# Layer: inception3a.branch3.0.conv, Type: Conv2d, Input Shape: (128, 28, 28), Output Shape: (16, 28, 28), MACs: 2408448
# Layer: inception3a.branch3.0.bn, Type: BatchNorm2d, Input Shape: (16, 28, 28), Output Shape: (16, 28, 28), MACs: 32
# Layer: inception3a.branch3.1.conv, Type: Conv2d, Input Shape: (16, 28, 28), Output Shape: (32, 28, 28), MACs: 3612672
# Layer: inception3a.branch3.1.bn, Type: BatchNorm2d, Input Shape: (32, 28, 28), Output Shape: (32, 28, 28), MACs: 64
# Layer: inception3a.branch4.0, Type: MaxPool2d, Input Shape: (32, 28, 28), Output Shape: (32, 28, 28), MACs: N/A
# Layer: inception3a.branch4.1.conv, Type: Conv2d, Input Shape: (32, 28, 28), Output Shape: (32, 28, 28), MACs: 4816896
# Layer: inception3a.branch4.1.bn, Type: BatchNorm2d, Input Shape: (32, 28, 28), Output Shape: (32, 28, 28), MACs: 64
# Layer: inception3b.branch1.conv, Type: Conv2d, Input Shape: (32, 28, 28), Output Shape: (128, 28, 28), MACs: 25690112
# Layer: inception3b.branch1.bn, Type: BatchNorm2d, Input Shape: (128, 28, 28), Output Shape: (128, 28, 28), MACs: 256
# Layer: inception3b.branch2.0.conv, Type: Conv2d, Input Shape: (128, 28, 28), Output Shape: (128, 28, 28), MACs: 25690112
# Layer: inception3b.branch2.0.bn, Type: BatchNorm2d, Input Shape: (128, 28, 28), Output Shape: (128, 28, 28), MACs: 256
# Layer: inception3b.branch2.1.conv, Type: Conv2d, Input Shape: (128, 28, 28), Output Shape: (192, 28, 28), MACs: 173408256
# Layer: inception3b.branch2.1.bn, Type: BatchNorm2d, Input Shape: (192, 28, 28), Output Shape: (192, 28, 28), MACs: 384
# Layer: inception3b.branch3.0.conv, Type: Conv2d, Input Shape: (192, 28, 28), Output Shape: (32, 28, 28), MACs: 6422528
# Layer: inception3b.branch3.0.bn, Type: BatchNorm2d, Input Shape: (32, 28, 28), Output Shape: (32, 28, 28), MACs: 64
# Layer: inception3b.branch3.1.conv, Type: Conv2d, Input Shape: (32, 28, 28), Output Shape: (96, 28, 28), MACs: 21676032
# Layer: inception3b.branch3.1.bn, Type: BatchNorm2d, Input Shape: (96, 28, 28), Output Shape: (96, 28, 28), MACs: 192
# Layer: inception3b.branch4.0, Type: MaxPool2d, Input Shape: (96, 28, 28), Output Shape: (96, 28, 28), MACs: N/A
# Layer: inception3b.branch4.1.conv, Type: Conv2d, Input Shape: (96, 28, 28), Output Shape: (64, 28, 28), MACs: 12845056
# Layer: inception3b.branch4.1.bn, Type: BatchNorm2d, Input Shape: (64, 28, 28), Output Shape: (64, 28, 28), MACs: 128
# Layer: maxpool3, Type: MaxPool2d, Input Shape: (64, 28, 28), Output Shape: (64, 14, 14), MACs: N/A
# Layer: inception4a.branch1.conv, Type: Conv2d, Input Shape: (64, 14, 14), Output Shape: (192, 14, 14), MACs: 18063360
# Layer: inception4a.branch1.bn, Type: BatchNorm2d, Input Shape: (192, 14, 14), Output Shape: (192, 14, 14), MACs: 384
# Layer: inception4a.branch2.0.conv, Type: Conv2d, Input Shape: (192, 14, 14), Output Shape: (96, 14, 14), MACs: 9031680
# Layer: inception4a.branch2.0.bn, Type: BatchNorm2d, Input Shape: (96, 14, 14), Output Shape: (96, 14, 14), MACs: 192
# Layer: inception4a.branch2.1.conv, Type: Conv2d, Input Shape: (96, 14, 14), Output Shape: (208, 14, 14), MACs: 35223552
# Layer: inception4a.branch2.1.bn, Type: BatchNorm2d, Input Shape: (208, 14, 14), Output Shape: (208, 14, 14), MACs: 416
# Layer: inception4a.branch3.0.conv, Type: Conv2d, Input Shape: (208, 14, 14), Output Shape: (16, 14, 14), MACs: 1505280
# Layer: inception4a.branch3.0.bn, Type: BatchNorm2d, Input Shape: (16, 14, 14), Output Shape: (16, 14, 14), MACs: 32
# Layer: inception4a.branch3.1.conv, Type: Conv2d, Input Shape: (16, 14, 14), Output Shape: (48, 14, 14), MACs: 1354752
# Layer: inception4a.branch3.1.bn, Type: BatchNorm2d, Input Shape: (48, 14, 14), Output Shape: (48, 14, 14), MACs: 96
# Layer: inception4a.branch4.0, Type: MaxPool2d, Input Shape: (48, 14, 14), Output Shape: (48, 14, 14), MACs: N/A
# Layer: inception4a.branch4.1.conv, Type: Conv2d, Input Shape: (48, 14, 14), Output Shape: (64, 14, 14), MACs: 6021120
# Layer: inception4a.branch4.1.bn, Type: BatchNorm2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: 128
# Layer: inception4b.branch1.conv, Type: Conv2d, Input Shape: (64, 14, 14), Output Shape: (160, 14, 14), MACs: 16056320
# Layer: inception4b.branch1.bn, Type: BatchNorm2d, Input Shape: (160, 14, 14), Output Shape: (160, 14, 14), MACs: 320
# Layer: inception4b.branch2.0.conv, Type: Conv2d, Input Shape: (160, 14, 14), Output Shape: (112, 14, 14), MACs: 11239424
# Layer: inception4b.branch2.0.bn, Type: BatchNorm2d, Input Shape: (112, 14, 14), Output Shape: (112, 14, 14), MACs: 224
# Layer: inception4b.branch2.1.conv, Type: Conv2d, Input Shape: (112, 14, 14), Output Shape: (224, 14, 14), MACs: 44255232
# Layer: inception4b.branch2.1.bn, Type: BatchNorm2d, Input Shape: (224, 14, 14), Output Shape: (224, 14, 14), MACs: 448
# Layer: inception4b.branch3.0.conv, Type: Conv2d, Input Shape: (224, 14, 14), Output Shape: (24, 14, 14), MACs: 2408448
# Layer: inception4b.branch3.0.bn, Type: BatchNorm2d, Input Shape: (24, 14, 14), Output Shape: (24, 14, 14), MACs: 48
# Layer: inception4b.branch3.1.conv, Type: Conv2d, Input Shape: (24, 14, 14), Output Shape: (64, 14, 14), MACs: 2709504
# Layer: inception4b.branch3.1.bn, Type: BatchNorm2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: 128
# Layer: inception4b.branch4.0, Type: MaxPool2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: N/A
# Layer: inception4b.branch4.1.conv, Type: Conv2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: 6422528
# Layer: inception4b.branch4.1.bn, Type: BatchNorm2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: 128
# Layer: inception4c.branch1.conv, Type: Conv2d, Input Shape: (64, 14, 14), Output Shape: (128, 14, 14), MACs: 12845056
# Layer: inception4c.branch1.bn, Type: BatchNorm2d, Input Shape: (128, 14, 14), Output Shape: (128, 14, 14), MACs: 256
# Layer: inception4c.branch2.0.conv, Type: Conv2d, Input Shape: (128, 14, 14), Output Shape: (128, 14, 14), MACs: 12845056
# Layer: inception4c.branch2.0.bn, Type: BatchNorm2d, Input Shape: (128, 14, 14), Output Shape: (128, 14, 14), MACs: 256
# Layer: inception4c.branch2.1.conv, Type: Conv2d, Input Shape: (128, 14, 14), Output Shape: (256, 14, 14), MACs: 57802752
# Layer: inception4c.branch2.1.bn, Type: BatchNorm2d, Input Shape: (256, 14, 14), Output Shape: (256, 14, 14), MACs: 512
# Layer: inception4c.branch3.0.conv, Type: Conv2d, Input Shape: (256, 14, 14), Output Shape: (24, 14, 14), MACs: 2408448
# Layer: inception4c.branch3.0.bn, Type: BatchNorm2d, Input Shape: (24, 14, 14), Output Shape: (24, 14, 14), MACs: 48
# Layer: inception4c.branch3.1.conv, Type: Conv2d, Input Shape: (24, 14, 14), Output Shape: (64, 14, 14), MACs: 2709504
# Layer: inception4c.branch3.1.bn, Type: BatchNorm2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: 128
# Layer: inception4c.branch4.0, Type: MaxPool2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: N/A
# Layer: inception4c.branch4.1.conv, Type: Conv2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: 6422528
# Layer: inception4c.branch4.1.bn, Type: BatchNorm2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: 128
# Layer: inception4d.branch1.conv, Type: Conv2d, Input Shape: (64, 14, 14), Output Shape: (112, 14, 14), MACs: 11239424
# Layer: inception4d.branch1.bn, Type: BatchNorm2d, Input Shape: (112, 14, 14), Output Shape: (112, 14, 14), MACs: 224
# Layer: inception4d.branch2.0.conv, Type: Conv2d, Input Shape: (112, 14, 14), Output Shape: (144, 14, 14), MACs: 14450688
# Layer: inception4d.branch2.0.bn, Type: BatchNorm2d, Input Shape: (144, 14, 14), Output Shape: (144, 14, 14), MACs: 288
# Layer: inception4d.branch2.1.conv, Type: Conv2d, Input Shape: (144, 14, 14), Output Shape: (288, 14, 14), MACs: 73156608
# Layer: inception4d.branch2.1.bn, Type: BatchNorm2d, Input Shape: (288, 14, 14), Output Shape: (288, 14, 14), MACs: 576
# Layer: inception4d.branch3.0.conv, Type: Conv2d, Input Shape: (288, 14, 14), Output Shape: (32, 14, 14), MACs: 3211264
# Layer: inception4d.branch3.0.bn, Type: BatchNorm2d, Input Shape: (32, 14, 14), Output Shape: (32, 14, 14), MACs: 64
# Layer: inception4d.branch3.1.conv, Type: Conv2d, Input Shape: (32, 14, 14), Output Shape: (64, 14, 14), MACs: 3612672
# Layer: inception4d.branch3.1.bn, Type: BatchNorm2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: 128
# Layer: inception4d.branch4.0, Type: MaxPool2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: N/A
# Layer: inception4d.branch4.1.conv, Type: Conv2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: 6422528
# Layer: inception4d.branch4.1.bn, Type: BatchNorm2d, Input Shape: (64, 14, 14), Output Shape: (64, 14, 14), MACs: 128
# Layer: inception4e.branch1.conv, Type: Conv2d, Input Shape: (64, 14, 14), Output Shape: (256, 14, 14), MACs: 26492928
# Layer: inception4e.branch1.bn, Type: BatchNorm2d, Input Shape: (256, 14, 14), Output Shape: (256, 14, 14), MACs: 512
# Layer: inception4e.branch2.0.conv, Type: Conv2d, Input Shape: (256, 14, 14), Output Shape: (160, 14, 14), MACs: 16558080
# Layer: inception4e.branch2.0.bn, Type: BatchNorm2d, Input Shape: (160, 14, 14), Output Shape: (160, 14, 14), MACs: 320
# Layer: inception4e.branch2.1.conv, Type: Conv2d, Input Shape: (160, 14, 14), Output Shape: (320, 14, 14), MACs: 90316800
# Layer: inception4e.branch2.1.bn, Type: BatchNorm2d, Input Shape: (320, 14, 14), Output Shape: (320, 14, 14), MACs: 640
# Layer: inception4e.branch3.0.conv, Type: Conv2d, Input Shape: (320, 14, 14), Output Shape: (32, 14, 14), MACs: 3311616
# Layer: inception4e.branch3.0.bn, Type: BatchNorm2d, Input Shape: (32, 14, 14), Output Shape: (32, 14, 14), MACs: 64
# Layer: inception4e.branch3.1.conv, Type: Conv2d, Input Shape: (32, 14, 14), Output Shape: (128, 14, 14), MACs: 7225344
# Layer: inception4e.branch3.1.bn, Type: BatchNorm2d, Input Shape: (128, 14, 14), Output Shape: (128, 14, 14), MACs: 256
# Layer: inception4e.branch4.0, Type: MaxPool2d, Input Shape: (128, 14, 14), Output Shape: (128, 14, 14), MACs: N/A
# Layer: inception4e.branch4.1.conv, Type: Conv2d, Input Shape: (128, 14, 14), Output Shape: (128, 14, 14), MACs: 13246464
# Layer: inception4e.branch4.1.bn, Type: BatchNorm2d, Input Shape: (128, 14, 14), Output Shape: (128, 14, 14), MACs: 256
# Layer: maxpool4, Type: MaxPool2d, Input Shape: (128, 14, 14), Output Shape: (128, 7, 7), MACs: N/A
# Layer: inception5a.branch1.conv, Type: Conv2d, Input Shape: (128, 7, 7), Output Shape: (256, 7, 7), MACs: 10436608
# Layer: inception5a.branch1.bn, Type: BatchNorm2d, Input Shape: (256, 7, 7), Output Shape: (256, 7, 7), MACs: 512
# Layer: inception5a.branch2.0.conv, Type: Conv2d, Input Shape: (256, 7, 7), Output Shape: (160, 7, 7), MACs: 6522880
# Layer: inception5a.branch2.0.bn, Type: BatchNorm2d, Input Shape: (160, 7, 7), Output Shape: (160, 7, 7), MACs: 320
# Layer: inception5a.branch2.1.conv, Type: Conv2d, Input Shape: (160, 7, 7), Output Shape: (320, 7, 7), MACs: 22579200
# Layer: inception5a.branch2.1.bn, Type: BatchNorm2d, Input Shape: (320, 7, 7), Output Shape: (320, 7, 7), MACs: 640
# Layer: inception5a.branch3.0.conv, Type: Conv2d, Input Shape: (320, 7, 7), Output Shape: (32, 7, 7), MACs: 1304576
# Layer: inception5a.branch3.0.bn, Type: BatchNorm2d, Input Shape: (32, 7, 7), Output Shape: (32, 7, 7), MACs: 64
# Layer: inception5a.branch3.1.conv, Type: Conv2d, Input Shape: (32, 7, 7), Output Shape: (128, 7, 7), MACs: 1806336
# Layer: inception5a.branch3.1.bn, Type: BatchNorm2d, Input Shape: (128, 7, 7), Output Shape: (128, 7, 7), MACs: 256
# Layer: inception5a.branch4.0, Type: MaxPool2d, Input Shape: (128, 7, 7), Output Shape: (128, 7, 7), MACs: N/A
# Layer: inception5a.branch4.1.conv, Type: Conv2d, Input Shape: (128, 7, 7), Output Shape: (128, 7, 7), MACs: 5218304
# Layer: inception5a.branch4.1.bn, Type: BatchNorm2d, Input Shape: (128, 7, 7), Output Shape: (128, 7, 7), MACs: 256
# Layer: inception5b.branch1.conv, Type: Conv2d, Input Shape: (128, 7, 7), Output Shape: (384, 7, 7), MACs: 15654912
# Layer: inception5b.branch1.bn, Type: BatchNorm2d, Input Shape: (384, 7, 7), Output Shape: (384, 7, 7), MACs: 768
# Layer: inception5b.branch2.0.conv, Type: Conv2d, Input Shape: (384, 7, 7), Output Shape: (192, 7, 7), MACs: 7827456
# Layer: inception5b.branch2.0.bn, Type: BatchNorm2d, Input Shape: (192, 7, 7), Output Shape: (192, 7, 7), MACs: 384
# Layer: inception5b.branch2.1.conv, Type: Conv2d, Input Shape: (192, 7, 7), Output Shape: (384, 7, 7), MACs: 32514048
# Layer: inception5b.branch2.1.bn, Type: BatchNorm2d, Input Shape: (384, 7, 7), Output Shape: (384, 7, 7), MACs: 768
# Layer: inception5b.branch3.0.conv, Type: Conv2d, Input Shape: (384, 7, 7), Output Shape: (48, 7, 7), MACs: 1956864
# Layer: inception5b.branch3.0.bn, Type: BatchNorm2d, Input Shape: (48, 7, 7), Output Shape: (48, 7, 7), MACs: 96
# Layer: inception5b.branch3.1.conv, Type: Conv2d, Input Shape: (48, 7, 7), Output Shape: (128, 7, 7), MACs: 2709504
# Layer: inception5b.branch3.1.bn, Type: BatchNorm2d, Input Shape: (128, 7, 7), Output Shape: (128, 7, 7), MACs: 256
# Layer: inception5b.branch4.0, Type: MaxPool2d, Input Shape: (128, 7, 7), Output Shape: (128, 7, 7), MACs: N/A
# Layer: inception5b.branch4.1.conv, Type: Conv2d, Input Shape: (128, 7, 7), Output Shape: (128, 7, 7), MACs: 5218304
# Layer: inception5b.branch4.1.bn, Type: BatchNorm2d, Input Shape: (128, 7, 7), Output Shape: (128, 7, 7), MACs: 256
# Layer: fc, Type: Linear, Input Shape: (128, 7, 7), Output Shape: (1000,), MACs: 1025000
# Total MACs: 1498391752

# %% [markdown]
# ## 2-1-5. Use forward hooks to extract the output activations of the Conv2d layers.

# %%
import torch
import torchvision.models as models
activation = {}
# Define a hook function
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook
model.eval()

# Register hook to each linear layer
for layer_name, layer in model.named_modules():
    if isinstance(layer, torch.nn.Conv2d):
        # Register forward hook
        layer.register_forward_hook(get_activation(layer_name))
# input_shape = (3, 224, 224)
data = torch.randn(1, 3, 224, 224)
output = model(data)

# Access the saved activations
for layer in activation:
    print(f"Activation from layer {layer}: {activation[layer].shape}")
# Out:
# Activation from layer conv1.conv: torch.Size([1, 64, 112, 112])
# Activation from layer conv2.conv: torch.Size([1, 64, 56, 56])
# Activation from layer conv3.conv: torch.Size([1, 192, 56, 56])
# Activation from layer inception3a.branch1.conv: torch.Size([1, 64, 28, 28])
# Activation from layer inception3a.branch2.0.conv: torch.Size([1, 96, 28, 28])
# Activation from layer inception3a.branch2.1.conv: torch.Size([1, 128, 28, 28])
# Activation from layer inception3a.branch3.0.conv: torch.Size([1, 16, 28, 28])
# Activation from layer inception3a.branch3.1.conv: torch.Size([1, 32, 28, 28])
# Activation from layer inception3a.branch4.1.conv: torch.Size([1, 32, 28, 28])
# Activation from layer inception3b.branch1.conv: torch.Size([1, 128, 28, 28])
# Activation from layer inception3b.branch2.0.conv: torch.Size([1, 128, 28, 28])
# Activation from layer inception3b.branch2.1.conv: torch.Size([1, 192, 28, 28])
# Activation from layer inception3b.branch3.0.conv: torch.Size([1, 32, 28, 28])
# Activation from layer inception3b.branch3.1.conv: torch.Size([1, 96, 28, 28])
# Activation from layer inception3b.branch4.1.conv: torch.Size([1, 64, 28, 28])
# Activation from layer inception4a.branch1.conv: torch.Size([1, 192, 14, 14])
# Activation from layer inception4a.branch2.0.conv: torch.Size([1, 96, 14, 14])
# Activation from layer inception4a.branch2.1.conv: torch.Size([1, 208, 14, 14])
# Activation from layer inception4a.branch3.0.conv: torch.Size([1, 16, 14, 14])
# Activation from layer inception4a.branch3.1.conv: torch.Size([1, 48, 14, 14])
# Activation from layer inception4a.branch4.1.conv: torch.Size([1, 64, 14, 14])
# Activation from layer inception4b.branch1.conv: torch.Size([1, 160, 14, 14])
# Activation from layer inception4b.branch2.0.conv: torch.Size([1, 112, 14, 14])
# Activation from layer inception4b.branch2.1.conv: torch.Size([1, 224, 14, 14])
# Activation from layer inception4b.branch3.0.conv: torch.Size([1, 24, 14, 14])
# Activation from layer inception4b.branch3.1.conv: torch.Size([1, 64, 14, 14])
# Activation from layer inception4b.branch4.1.conv: torch.Size([1, 64, 14, 14])
# Activation from layer inception4c.branch1.conv: torch.Size([1, 128, 14, 14])
# Activation from layer inception4c.branch2.0.conv: torch.Size([1, 128, 14, 14])
# Activation from layer inception4c.branch2.1.conv: torch.Size([1, 256, 14, 14])
# Activation from layer inception4c.branch3.0.conv: torch.Size([1, 24, 14, 14])
# Activation from layer inception4c.branch3.1.conv: torch.Size([1, 64, 14, 14])
# Activation from layer inception4c.branch4.1.conv: torch.Size([1, 64, 14, 14])
# Activation from layer inception4d.branch1.conv: torch.Size([1, 112, 14, 14])
# Activation from layer inception4d.branch2.0.conv: torch.Size([1, 144, 14, 14])
# Activation from layer inception4d.branch2.1.conv: torch.Size([1, 288, 14, 14])
# Activation from layer inception4d.branch3.0.conv: torch.Size([1, 32, 14, 14])
# Activation from layer inception4d.branch3.1.conv: torch.Size([1, 64, 14, 14])
# Activation from layer inception4d.branch4.1.conv: torch.Size([1, 64, 14, 14])
# Activation from layer inception4e.branch1.conv: torch.Size([1, 256, 14, 14])
# Activation from layer inception4e.branch2.0.conv: torch.Size([1, 160, 14, 14])
# Activation from layer inception4e.branch2.1.conv: torch.Size([1, 320, 14, 14])
# Activation from layer inception4e.branch3.0.conv: torch.Size([1, 32, 14, 14])
# Activation from layer inception4e.branch3.1.conv: torch.Size([1, 128, 14, 14])
# Activation from layer inception4e.branch4.1.conv: torch.Size([1, 128, 14, 14])
# Activation from layer inception5a.branch1.conv: torch.Size([1, 256, 7, 7])
# Activation from layer inception5a.branch2.0.conv: torch.Size([1, 160, 7, 7])
# Activation from layer inception5a.branch2.1.conv: torch.Size([1, 320, 7, 7])
# Activation from layer inception5a.branch3.0.conv: torch.Size([1, 32, 7, 7])
# Activation from layer inception5a.branch3.1.conv: torch.Size([1, 128, 7, 7])
# Activation from layer inception5a.branch4.1.conv: torch.Size([1, 128, 7, 7])
# Activation from layer inception5b.branch1.conv: torch.Size([1, 384, 7, 7])
# Activation from layer inception5b.branch2.0.conv: torch.Size([1, 192, 7, 7])
# Activation from layer inception5b.branch2.1.conv: torch.Size([1, 384, 7, 7])
# Activation from layer inception5b.branch3.0.conv: torch.Size([1, 48, 7, 7])
# Activation from layer inception5b.branch3.1.conv: torch.Size([1, 128, 7, 7])
# Activation from layer inception5b.branch4.1.conv: torch.Size([1, 128, 7, 7])
# Activation from layer fc: torch.Size([1, 1000])
